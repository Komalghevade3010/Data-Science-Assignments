# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/gheva/OneDrive/Desktop/sales_data_with_discounts.csv")
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %% [markdown]
# ## Descriptive Analytics for Numerical Columns ##

# %%
df.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102960
# 2      16100             112700           9.456886     10657.910160
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0     160346.50120
# 1      89323.89704
# 2     102042.08980
# 3     112235.92530
# 4      19927.05377

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'Volume', 'BU', 'Brand', 'Model',
#        'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
numerical_columns=df.select_dtypes(include=['number']).columns

# %%
print("Numerical Columns:",numerical_columns)
# Out:
# Numerical Columns: Index(['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Date                  object
# Day                   object
# SKU                   object
# City                  object
# Volume                 int64
# BU                    object
# Brand                 object
# Model                 object
# Avg Price              int64
# Total Sales Value      int64
# Discount Rate (%)    float64
# Discount Amount      float64
# Net Sales Value      float64
# dtype: object

# %%
df.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495426     47847.912855
# ...

# %%
numerical_columns=df.select_dtypes(include='number')

# %%
modes=numerical_columns.apply(lambda col: col.mode().iloc[0])
print(modes)
# Out:
# Volume                   3.000000
# Avg Price              400.000000
# Total Sales Value    24300.000000
# Discount Rate (%)        5.007822
# Discount Amount         69.177942
# Net Sales Value        326.974801
# dtype: float64

# %% [markdown]
# ## Interpretation##

# %% [markdown]
# The mean ,median and standard deviation for all the numerical columns is calculated by using the describe function.The mean,median,standard deviation and mode of total sales value column is higher than other columns.

# %% [markdown]
# ## Data Visualization##

# %% [markdown]
# # Histogram #

# %%
plt.hist(df.Volume)
# Out:
# (array([213., 137.,  49.,  26.,  15.,   2.,   0.,   4.,   1.,   3.]),
#  array([ 1.,  4.,  7., 10., 13., 16., 19., 22., 25., 28., 31.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
#  # Interpretation #
#  In the volume column the data is right skewed and outliers are present in the data.

# %% [markdown]
# ## BOXPLOTS##

# %%
plt.boxplot(df.Volume)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29b01aafc50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x29b01ba69c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x29b01b611c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x29b01ba6e70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x29b01ba71a0>],
#  'means': []}

# %% [markdown]
# # Interpretation#
# In the above boxplot some data points are lies outside the upper quartile range so we can say that there is outliers present in the volume column.

# %% [markdown]
# ## Bar Chart analysis for categorical columns##

# %%
categorial_columns=df.select_dtypes(include=['object','category']).columns

# %%
print("categorial Columns:",categorial_columns)
# Out:
# categorial Columns: Index(['Date', 'Day', 'SKU', 'City', 'BU', 'Brand', 'Model'], dtype='object')

# %%
df['Brand'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Brand'>

# %% [markdown]
# # Interpretation#
# From above bar chart we can conclude that Jeera brand has more sales than others. Sumsang and Orange has less sales.

# %% [markdown]
# ## Standardization of Numerical Variables ##

# %% [markdown]
#      Standardization is a scaling method where the values are centered around mean with a unit standard deviation.It means if we will calculate mean and standard deviation of standard scores it will be 0(mean) and 1(standard deviation) respectively.
#      When we combine different magnitude columns in a single data set and when certain analysis is applied high magnitude column would dominate entire analysis.Low magnitude column will have a very little room to play analysis.so when you apply analysis on such dataset there would be a biasness in final analysis. so it remove this scaling effect,we will go for z-scores or data standardization.z-score range is -3 to 3.

# %%
X=df['Volume']
X
# Out:
# 0      15
# 1      10
# 2       7
# 3       6
# 4       3
#        ..
# 445     2
# 446     6
# 447     2
# 448     3
# 449     1
# Name: Volume, Length: 450, dtype: int64

# %%
mean=df['Volume'].mean()
mean
# Out:
# 5.066666666666666

# %%
std_dev=df['Volume'].std()
std_dev
# Out:
# 4.231602391213926

# %%
z_Volume=(X-mean)/std_dev
z_Volume
# Out:
# 0      2.347417
# 1      1.165831
# 2      0.456880
# 3      0.220563
# 4     -0.488389
#          ...
# 445   -0.724706
# 446    0.220563
# 447   -0.724706
# 448   -0.488389
# 449   -0.961023
# Name: Volume, Length: 450, dtype: float64

# %% [markdown]
# ## Conversion of Categorical Data into Dummy Variables ##

# %% [markdown]
#            If our dataset contains categorical data then there is no possible to apply machine learning algorithm because ML algorithm
# performs only on numerical columns.So we need to convert that categoricalmcolumns into the numerical ones.so in that case we use Dummy variable
# method on that columns and get the numerical columns.

# %%
df=pd.get_dummies(data=df,columns=['Brand'])

# %%
df
# Out:
#            Date       Day  SKU City  Volume         BU       Model  Avg Price  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles       RU-10      12100
# 1    01-04-2021  Thursday  M02    C      10    Mobiles   RU-9 Plus      10100
# 2    01-04-2021  Thursday  M03    C       7    Mobiles       YM-99      16100
# 3    01-04-2021  Thursday  M04    C       6    Mobiles  YM-99 Plus      20100
# 4    01-04-2021  Thursday  M05    C       3    Mobiles      YM-98        8100
# ..          ...       ...  ...  ...     ...        ...         ...        ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle   M-Casuals       1300
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   W-Western       2600
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle    W-Lounge       1600
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle   M-Formals       1900
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle     M-Shoes       3100
#
# ...

# %%
df=pd.get_dummies(data=df,columns=['BU'])
df
# Out:
#            Date       Day  SKU City  Volume  Brand       Model  Avg Price  \
# 0    01-04-2021  Thursday  M01    C      15  RealU       RU-10      12100
# 1    01-04-2021  Thursday  M02    C      10  RealU   RU-9 Plus      10100
# 2    01-04-2021  Thursday  M03    C       7   YouM       YM-99      16100
# 3    01-04-2021  Thursday  M04    C       6   YouM  YM-99 Plus      20100
# 4    01-04-2021  Thursday  M05    C       3   YouM      YM-98        8100
# ..          ...       ...  ...  ...     ...    ...         ...        ...
# 445  15-04-2021  Thursday  L06    C       2  Jeera   M-Casuals       1300
# 446  15-04-2021  Thursday  L07    C       6   Viva   W-Western       2600
# 447  15-04-2021  Thursday  L08    C       2   Viva    W-Lounge       1600
# 448  15-04-2021  Thursday  L09    C       3  Jeera   M-Formals       1900
# 449  15-04-2021  Thursday  L10    C       1  Jeera     M-Shoes       3100
#
#      Total Sales Value  Discount Rate (%)  Discount Amount  Net Sales Value  \
# ...
