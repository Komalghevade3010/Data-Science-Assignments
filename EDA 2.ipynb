# %% [markdown]
# ## Data Exploration and Preprocessing##

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/gheva/OneDrive/Desktop/Adults_with_headers.csv")
df
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df.tail(10)
# Out:
#        age      workclass  fnlwgt      education  education_num  \
# 32551   32        Private   34066           10th              6
# 32552   43        Private   84661      Assoc-voc             11
# 32553   32        Private  116138        Masters             14
# 32554   53        Private  321865        Masters             14
# 32555   22        Private  310152   Some-college             10
# 32556   27        Private  257302     Assoc-acdm             12
# 32557   40        Private  154374        HS-grad              9
# 32558   58        Private  151910        HS-grad              9
# 32559   22        Private  201490        HS-grad              9
# 32560   52   Self-emp-inc  287927        HS-grad              9
#
#             marital_status          occupation    relationship  \
# 32551   Married-civ-spouse   Handlers-cleaners         Husband
# 32552   Married-civ-spouse               Sales         Husband
# 32553        Never-married        Tech-support   Not-in-family
# ...

# %%
df.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours_per_week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital_gain       int64
# capital_loss       int64
# hours_per_week     int64
# native_country    object
# income            object
# dtype: object

# %%
df.isna()
# Out:
#          age  workclass  fnlwgt  education  education_num  marital_status  \
# 0      False      False   False      False          False           False
# 1      False      False   False      False          False           False
# 2      False      False   False      False          False           False
# 3      False      False   False      False          False           False
# 4      False      False   False      False          False           False
# ...      ...        ...     ...        ...            ...             ...
# 32556  False      False   False      False          False           False
# 32557  False      False   False      False          False           False
# 32558  False      False   False      False          False           False
# 32559  False      False   False      False          False           False
# 32560  False      False   False      False          False           False
#
#        occupation  relationship   race    sex  capital_gain  capital_loss  \
# ...

# %%
df.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %% [markdown]
# ## No missing values are present in the dataset ##

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
df.drop(columns=['workclass','education','marital_status','occupation','relationship','race','sex','native_country','income'],inplace=True)

# %%
df
# Out:
#        age  fnlwgt  education_num  capital_gain  capital_loss  hours_per_week
# 0       39   77516             13          2174             0              40
# 1       50   83311             13             0             0              13
# 2       38  215646              9             0             0              40
# 3       53  234721              7             0             0              40
# 4       28  338409             13             0             0              40
# ...    ...     ...            ...           ...           ...             ...
# 32556   27  257302             12             0             0              38
# 32557   40  154374              9             0             0              40
# 32558   58  151910              9             0             0              40
# 32559   22  201490              9             0             0              20
# 32560   52  287927              9         15024             0              40
#
# [32561 rows x 6 columns]

# %%
# Standardization
sc = StandardScaler()

# %%
sc.fit_transform(df)
# Out:
# array([[ 0.03067056, -1.06361075,  1.13473876,  0.1484529 , -0.21665953,
#         -0.03542945],
#        [ 0.83710898, -1.008707  ,  1.13473876, -0.14592048, -0.21665953,
#         -2.22215312],
#        [-0.04264203,  0.2450785 , -0.42005962, -0.14592048, -0.21665953,
#         -0.03542945],
#        ...,
#        [ 1.42360965, -0.35877741, -0.42005962, -0.14592048, -0.21665953,
#         -0.03542945],
#        [-1.21564337,  0.11095988, -0.42005962, -0.14592048, -0.21665953,
#         -1.65522476],
#        [ 0.98373415,  0.92989258, -0.42005962,  1.88842434, -0.21665953,
#         -0.03542945]])

# %%
pd.DataFrame(sc.fit_transform(df))
# Out:
#               0         1         2         3        4         5
# 0      0.030671 -1.063611  1.134739  0.148453 -0.21666 -0.035429
# 1      0.837109 -1.008707  1.134739 -0.145920 -0.21666 -2.222153
# 2     -0.042642  0.245079 -0.420060 -0.145920 -0.21666 -0.035429
# 3      1.057047  0.425801 -1.197459 -0.145920 -0.21666 -0.035429
# 4     -0.775768  1.408176  1.134739 -0.145920 -0.21666 -0.035429
# ...         ...       ...       ...       ...      ...       ...
# 32556 -0.849080  0.639741  0.746039 -0.145920 -0.21666 -0.197409
# 32557  0.103983 -0.335433 -0.420060 -0.145920 -0.21666 -0.035429
# 32558  1.423610 -0.358777 -0.420060 -0.145920 -0.21666 -0.035429
# 32559 -1.215643  0.110960 -0.420060 -0.145920 -0.21666 -1.655225
# 32560  0.983734  0.929893 -0.420060  1.888424 -0.21666 -0.035429
#
# [32561 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['age', 'fnlwgt', 'education_num', 'capital_gain', 'capital_loss',
#        'hours_per_week'],
#       dtype='object')

# %%
scaled_data = pd.DataFrame(sc.fit_transform(df),columns=df.columns)
scaled_data
# Out:
#             age    fnlwgt  education_num  capital_gain  capital_loss  \
# 0      0.030671 -1.063611       1.134739      0.148453      -0.21666
# 1      0.837109 -1.008707       1.134739     -0.145920      -0.21666
# 2     -0.042642  0.245079      -0.420060     -0.145920      -0.21666
# 3      1.057047  0.425801      -1.197459     -0.145920      -0.21666
# 4     -0.775768  1.408176       1.134739     -0.145920      -0.21666
# ...         ...       ...            ...           ...           ...
# 32556 -0.849080  0.639741       0.746039     -0.145920      -0.21666
# 32557  0.103983 -0.335433      -0.420060     -0.145920      -0.21666
# 32558  1.423610 -0.358777      -0.420060     -0.145920      -0.21666
# 32559 -1.215643  0.110960      -0.420060     -0.145920      -0.21666
# 32560  0.983734  0.929893      -0.420060      1.888424      -0.21666
#
#        hours_per_week
# 0           -0.035429
# 1           -2.222153
# 2           -0.035429
# 3           -0.035429
# ...

# %%
scaled_data.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  3.256100e+04  3.256100e+04   3.256100e+04  3.256100e+04  3.256100e+04
# mean  -2.705915e-17 -1.001625e-16   1.471887e-16  1.309314e-17  1.016900e-16
# std    1.000015e+00  1.000015e+00   1.000015e+00  1.000015e+00  1.000015e+00
# min   -1.582206e+00 -1.681631e+00  -3.529656e+00 -1.459205e-01 -2.166595e-01
# 25%   -7.757679e-01 -6.816910e-01  -4.200596e-01 -1.459205e-01 -2.166595e-01
# 50%   -1.159546e-01 -1.082193e-01  -3.136003e-02 -1.459205e-01 -2.166595e-01
# 75%    6.904838e-01  4.478765e-01   7.460392e-01 -1.459205e-01 -2.166595e-01
# max    3.769612e+00  1.226856e+01   2.300838e+00  1.339458e+01  1.059351e+01
#
#        hours_per_week
# count    3.256100e+04
# mean    -1.549355e-17
# std      1.000015e+00
# min     -3.194030e+00
# 25%     -3.542945e-02
# 50%     -3.542945e-02
# 75%      3.695194e-01
# max      4.742967e+00

# %% [markdown]
# ## MinMaxScalar##

# %%
mn = MinMaxScaler()

# %%
df.columns
# Out:
# Index(['age', 'fnlwgt', 'education_num', 'capital_gain', 'capital_loss',
#        'hours_per_week'],
#       dtype='object')

# %%
minmax_scaled = pd.DataFrame(mn.fit_transform(df), columns=df.columns)
minmax_scaled
# Out:
#             age    fnlwgt  education_num  capital_gain  capital_loss  \
# 0      0.301370  0.044302       0.800000      0.021740           0.0
# 1      0.452055  0.048238       0.800000      0.000000           0.0
# 2      0.287671  0.138113       0.533333      0.000000           0.0
# 3      0.493151  0.151068       0.400000      0.000000           0.0
# 4      0.150685  0.221488       0.800000      0.000000           0.0
# ...         ...       ...            ...           ...           ...
# 32556  0.136986  0.166404       0.733333      0.000000           0.0
# 32557  0.315068  0.096500       0.533333      0.000000           0.0
# 32558  0.561644  0.094827       0.533333      0.000000           0.0
# 32559  0.068493  0.128499       0.533333      0.000000           0.0
# 32560  0.479452  0.187203       0.533333      0.150242           0.0
#
#        hours_per_week
# 0            0.397959
# 1            0.122449
# 2            0.397959
# 3            0.397959
# ...

# %%
minmax_scaled.describe()
# Out:
#                 age        fnlwgt  education_num  capital_gain  capital_loss  \
# count  32561.000000  32561.000000   32561.000000  32561.000000  32561.000000
# mean       0.295639      0.120545       0.605379      0.010777      0.020042
# std        0.186855      0.071685       0.171515      0.073854      0.092507
# min        0.000000      0.000000       0.000000      0.000000      0.000000
# 25%        0.150685      0.071679       0.533333      0.000000      0.000000
# 50%        0.273973      0.112788       0.600000      0.000000      0.000000
# 75%        0.424658      0.152651       0.733333      0.000000      0.000000
# max        1.000000      1.000000       1.000000      1.000000      1.000000
#
#        hours_per_week
# count    32561.000000
# mean         0.402423
# std          0.125994
# min          0.000000
# 25%          0.397959
# 50%          0.397959
# 75%          0.448980
# max          1.000000

# %%
## Encoding Techniques##

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# %%
data=pd.read_csv("C:/Users/gheva/OneDrive/Desktop/Adults_with_headers.csv")
data
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
data.tail()
# Out:
#        age      workclass  fnlwgt    education  education_num  \
# 32556   27        Private  257302   Assoc-acdm             12
# 32557   40        Private  154374      HS-grad              9
# 32558   58        Private  151910      HS-grad              9
# 32559   22        Private  201490      HS-grad              9
# 32560   52   Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation relationship    race      sex  \
# 32556   Married-civ-spouse        Tech-support         Wife   White   Female
# 32557   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32558              Widowed        Adm-clerical    Unmarried   White   Female
# 32559        Never-married        Adm-clerical    Own-child   White     Male
# 32560   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        capital_gain  capital_loss  hours_per_week  native_country  income
# ...

# %%
data1=data.copy()

# %%
columns_to_encode=[6,7]

# %%
labelencoder = LabelEncoder()

# %%
for col in columns_to_encode:
    data1.iloc[:,col]=labelencoder.fit_transform(data1.iloc[:,col])

# %%
print(data1.head())
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status occupation relationship    race      sex  capital_gain  \
# 0        Never-married          1            1   White     Male          2174
# 1   Married-civ-spouse          4            0   White     Male             0
# 2             Divorced          6            1   White     Male             0
# 3   Married-civ-spouse          6            0   Black     Male             0
# 4   Married-civ-spouse         10            5   Black   Female             0
#
#    capital_loss  hours_per_week  native_country  income
# 0             0              40   United-States   <=50K
# ...

# %%
data1
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status occupation relationship    race      sex  \
# 0            Never-married          1            1   White     Male
# ...

# %% [markdown]
# ## One Hot Encoder##

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
data2=data.copy()

# %%
data2
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
column_to_encode=[2, 4, 8, 9, 10]
valid_indices=[i for i in column_to_encode if i<len(df.columns)]

# %%
columns_to_encode=[df.columns[i] for i in valid_indices]

# %%
data2_encoded=pd.get_dummies(data2,columns=columns_to_encode,drop_first=True)

# %%
data2=print(data2_encoded.head())
# Out:
#    age          workclass  fnlwgt   education       marital_status  \
# 0   39          State-gov   77516   Bachelors        Never-married
# 1   50   Self-emp-not-inc   83311   Bachelors   Married-civ-spouse
# 2   38            Private  215646     HS-grad             Divorced
# 3   53            Private  234721        11th   Married-civ-spouse
# 4   28            Private  338409   Bachelors   Married-civ-spouse
#
#            occupation    relationship    race      sex  capital_gain  ...  \
# 0        Adm-clerical   Not-in-family   White     Male          2174  ...
# 1     Exec-managerial         Husband   White     Male             0  ...
# 2   Handlers-cleaners   Not-in-family   White     Male             0  ...
# 3   Handlers-cleaners         Husband   Black     Male             0  ...
# 4      Prof-specialty            Wife   Black   Female             0  ...
#
#    capital_loss_2547 capital_loss_2559 capital_loss_2603  capital_loss_2754  \
# ...

# %% [markdown]
# ## Discuss the pros and cons of one hot encoding and label encoding ?##

# %%
One hot encoding transforms categories into multiple binary columns,where each category is represented by o and 1.
This method is useful for nominal data ,ideal for tree based models like Random Forest and XGBoost.
On the other hand,Label Encoding,assigns a unique integer to each category,making it efficient in terms of storage and computation.
                                      It works well for ordinal data.

# %% [markdown]
# ## Feature Engineering##

# %%
from pandas import read_csv
import pandas as pd
from numpy import set_printoptions
from sklearn.feature_selection import SelectKBest 
from sklearn.feature_selection import chi2

# %%
data1
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status occupation relationship    race      sex  \
# 0            Never-married          1            1   White     Male
# ...

# %%
data1.drop(columns=['workclass','education','marital_status','occupation','relationship','race','sex','native_country'],inplace=True)

# %%
data1
# Out:
#        age  fnlwgt  education_num  capital_gain  capital_loss  hours_per_week  \
# 0       39   77516             13          2174             0              40
# 1       50   83311             13             0             0              13
# 2       38  215646              9             0             0              40
# 3       53  234721              7             0             0              40
# 4       28  338409             13             0             0              40
# ...    ...     ...            ...           ...           ...             ...
# 32556   27  257302             12             0             0              38
# 32557   40  154374              9             0             0              40
# 32558   58  151910              9             0             0              40
# 32559   22  201490              9             0             0              20
# 32560   52  287927              9         15024             0              40
#
#        income
# 0       <=50K
# ...

# %%
data1.shape
# Out:
# (32561, 7)

# %%
X=data1.iloc[:,0:6]
Y=data1.iloc[:,6]

# %%
test = SelectKBest(score_func=chi2, k=4) 
fit = test.fit(X, Y)

# %%
set_printoptions(precision=2) 
print(fit.scores_)
# Out:
# [8.60e+03 1.71e+05 2.40e+03 8.22e+07 1.37e+06 6.48e+03]

# %%
x=pd.DataFrame(fit.scores_).T

# %%
x
# Out:
#              0              1            2             3             4  \
# 0  8600.611822  171147.682865  2401.421777  8.219247e+07  1.372146e+06
#
#              5
# 0  6476.408996

# %%
sorted_x = x.sort_values(by = 0, ascending=False, axis = 1)
sorted_x
# Out:
#               3             4              1            0            5  \
# 0  8.219247e+07  1.372146e+06  171147.682865  8600.611822  6476.408996
#
#              2
# 0  2401.421777

# %%
data1
# Out:
#        age  fnlwgt  education_num  capital_gain  capital_loss  hours_per_week  \
# 0       39   77516             13          2174             0              40
# 1       50   83311             13             0             0              13
# 2       38  215646              9             0             0              40
# 3       53  234721              7             0             0              40
# 4       28  338409             13             0             0              40
# ...    ...     ...            ...           ...           ...             ...
# 32556   27  257302             12             0             0              38
# 32557   40  154374              9             0             0              40
# 32558   58  151910              9             0             0              40
# 32559   22  201490              9             0             0              20
# 32560   52  287927              9         15024             0              40
#
#        income
# 0       <=50K
# ...

# %%
import pandas as pd
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression(max_iter=400)
rfe = RFE(model)
fit = rfe.fit(X, Y)

# %%
fit.n_features_
# Out:
# 3

# %%
fit.support_
# Out:
# array([ True, False,  True, False, False,  True])

# %%
fit.ranking_
# Out:
# array([1, 4, 1, 3, 2, 1])

# %%
from pandas import read_csv
from sklearn.tree import  DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()
model.fit(X, Y)
print(model.feature_importances_)
# Out:
# [0.2  0.39 0.11 0.16 0.05 0.08]

# %%
sorted_list=model.feature_importances_
print('Feature importance=',sorted_list)
sorted_list.sort()
print('Sorted Feature importance=',sorted_list)
# Out:
# Feature importance= [0.2  0.39 0.11 0.16 0.05 0.08]
# Sorted Feature importance= [0.05 0.08 0.11 0.16 0.2  0.39]

# %% [markdown]
# ## Feature Selection ##

# %%
from sklearn.ensemble import IsolationForest
import pandas as pd

# %%
data1
# Out:
#        age  fnlwgt  education_num  capital_gain  capital_loss  hours_per_week  \
# 0       39   77516             13          2174             0              40
# 1       50   83311             13             0             0              13
# 2       38  215646              9             0             0              40
# 3       53  234721              7             0             0              40
# 4       28  338409             13             0             0              40
# ...    ...     ...            ...           ...           ...             ...
# 32556   27  257302             12             0             0              38
# 32557   40  154374              9             0             0              40
# 32558   58  151910              9             0             0              40
# 32559   22  201490              9             0             0              20
# 32560   52  287927              9         15024             0              40
#
#        income
# 0       <=50K
# ...

# %%
data1.drop(columns=['income'],inplace=True)

# %%
iso=IsolationForest(random_state=10,contamination=0.1)
iso.fit(data1)
out=iso.predict(data1)

# %%
out
# Out:
# array([ 1,  1,  1, ...,  1,  1, -1])

# %%
df['Score']=out
df
# Out:
#        age  fnlwgt  education_num  capital_gain  capital_loss  hours_per_week  \
# 0       39   77516             13          2174             0              40
# 1       50   83311             13             0             0              13
# 2       38  215646              9             0             0              40
# 3       53  234721              7             0             0              40
# 4       28  338409             13             0             0              40
# ...    ...     ...            ...           ...           ...             ...
# 32556   27  257302             12             0             0              38
# 32557   40  154374              9             0             0              40
# 32558   58  151910              9             0             0              40
# 32559   22  201490              9             0             0              20
# 32560   52  287927              9         15024             0              40
#
#        Score
# 0          1
# ...

# %%
data =pd.read_csv("C:/Users/gheva/OneDrive/Desktop/Adults_with_headers.csv",index_col=0)
data_encoded=pd.get_dummies(data)

# %%
data_encoded
# Out:
#      fnlwgt  education_num  capital_gain  capital_loss  hours_per_week  \
# age
# 39    77516             13          2174             0              40
# 50    83311             13             0             0              13
# 38   215646              9             0             0              40
# 53   234721              7             0             0              40
# 28   338409             13             0             0              40
# ..      ...            ...           ...           ...             ...
# 27   257302             12             0             0              38
# 40   154374              9             0             0              40
# 58   151910              9             0             0              40
# 22   201490              9             0             0              20
# 52   287927              9         15024             0              40
#
#      workclass_ ?  workclass_ Federal-gov  workclass_ Local-gov  \
# age
# ...

# %%
clf = IsolationForest(random_state=10,contamination=.01)

clf.fit(data_encoded)
# Out:
# IsolationForest(contamination=0.01, random_state=10)

# %%
y_pred_outliers = clf.predict(data_encoded)

# %%
y_pred_outliers
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
data_encoded
# Out:
#      fnlwgt  education_num  capital_gain  capital_loss  hours_per_week  \
# age
# 39    77516             13          2174             0              40
# 50    83311             13             0             0              13
# 38   215646              9             0             0              40
# 53   234721              7             0             0              40
# 28   338409             13             0             0              40
# ..      ...            ...           ...           ...             ...
# 27   257302             12             0             0              38
# 40   154374              9             0             0              40
# 58   151910              9             0             0              40
# 22   201490              9             0             0              20
# 52   287927              9         15024             0              40
#
#      workclass_ ?  workclass_ Federal-gov  workclass_ Local-gov  \
# age
# ...

# %%
clf = IsolationForest(random_state=10,contamination=.01)
clf.fit(data_encoded)

y_pred_outliers = clf.predict(data_encoded)
y_pred_outliers
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %% [markdown]
# ## PPS Score##

# %%
# !pip
# Out:
# Usage:
#   pip <command> [options]
#
# Commands:
#   install                     Install packages.
#   download                    Download packages.
#   uninstall                   Uninstall packages.
#   freeze                      Output installed packages in requirements format.
#   inspect                     Inspect the python environment.
#   list                        List installed packages.
#   show                        Show information about installed packages.
#   check                       Verify installed packages have compatible dependencies.
#   config                      Manage local and global configuration.
#   search                      Search PyPI for packages.
#   cache                       Inspect and manage pip's wheel cache.
#   index                       Inspect information available from package indexes.
#   wheel                       Build wheels from your requirements.
#   hash                        Compute hashes of package archives.
# ...

# %%
# !pip install ppscore
# Out:
# ...
#   Using cached ppscore-1.3.0-py2.py3-none-any.whl
# ...
#   Using cached pandas-1.5.3.tar.gz (5.2 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: still running...
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Failed to build pandas
#   error: subprocess-exited-with-error
#
# ...
#   exit code: 1
#
#   [2527 lines of output]
#   <string>:19: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   C:\Users\gheva\AppData\Local\Temp\pip-build-env-0m9onwrp\overlay\Lib\site-packages\setuptools\dist.py:760: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#   !!
#
# ...

# %%
import ppscore as pps
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[183], line 1
# ----> 1 import ppscore as pps
#
# ModuleNotFoundError: No module named 'ppscore'

# %%
import pandas as pd

# %%
data =pd.read_csv("C:/Users/gheva/OneDrive/Desktop/Adults_with_headers.csv",index_col=0)

# %%
data.head()
# Out:
#              workclass  fnlwgt   education  education_num  \
# age
# 39           State-gov   77516   Bachelors             13
# 50    Self-emp-not-inc   83311   Bachelors             13
# 38             Private  215646     HS-grad              9
# 53             Private  234721        11th              7
# 28             Private  338409   Bachelors             13
#
#           marital_status          occupation    relationship    race      sex  \
# age
# 39         Never-married        Adm-clerical   Not-in-family   White     Male
# 50    Married-civ-spouse     Exec-managerial         Husband   White     Male
# 38              Divorced   Handlers-cleaners   Not-in-family   White     Male
# 53    Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 28    Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#      capital_gain  capital_loss  hours_per_week  native_country  income
# age
# ...

# %%
pps.score(data,"age", "sex")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 pps.score(data,"age", "sex")
#
# NameError: name 'pps' is not defined

# %%
pps.matrix(data)

# %%
df=pd.DataFrame(pps.matrix(data))
df[df.case!='predict_itself'].iloc[:,[0,1,2,3,5,8]].sort_values('ppscore',ascending=False)
